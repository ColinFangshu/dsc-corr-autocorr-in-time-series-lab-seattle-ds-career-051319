# %% [markdown]
# # Correlation and Autocorrelation in Time Series - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, You'll practice your knowledge on correlation, autocorrelation and the ACF and PACF.

# %% [markdown]
# ## Objectives
#
# You will be able to:
# - Understand correlation in Time Series
# - Plot and discuss the autocorrelation function (ACF) for a time-series
# - Plot and discuss the partial autocorrelation function (PACF) for a time-series
# - Interpret ACF and PACF and Identify use cases both functions

# %% [markdown]
# ## The Exchange Rate Data

# %% [markdown]
# We'll be looking at the exchange rates dataset again. First, import the necessary libraries for time series and plotting. Then import the data (in `exch_rates.csv`) and make sure it's set in the correct time series format with the `datetime` as the index.

# %%
# your code here
import pandas as pd
import numpy as np
import pandas.tseries 
import matplotlib.pyplot as plt

# %%
# your code here
df = pd.read_csv('exch_rates.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6905 entries, 0 to 6904
# Data columns (total 4 columns):
# Frequency            6905 non-null object
# Euro                 4838 non-null float64
# Australian Dollar    4838 non-null float64
# Danish Krone         4838 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 215.9+ KB

# %%
df.Frequency = pd.to_datetime(df.Frequency)
df.set_index('Frequency', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6905 entries, 2000-01-01 to 2018-11-26
# Data columns (total 3 columns):
# Euro                 4838 non-null float64
# Australian Dollar    4838 non-null float64
# Danish Krone         4838 non-null float64
# dtypes: float64(3)
# memory usage: 215.8 KB

# %% [markdown]
# Plot the three exchange rates in one plot

# %%
# your code here
df.plot(figsize=(15,5),legend=True)
plt.show()

# %% [markdown]
# You can see that the EUR/USD and AUD/USD exchange rate are somewhere between rougly 0.5 and 2 between 2000 and 2018, where the Danish Krone is somewhere between roughly 4.5 and 9. Now let's look at the correlations between these time series.

# %%
# your code here
df.corr()
# Out:
#                        Euro  Australian Dollar  Danish Krone
# Euro               1.000000           0.883181      0.999952
# Australian Dollar  0.883181           1.000000      0.882513
# Danish Krone       0.999952           0.882513      1.000000

# %% [markdown]
# ### What is your conclusion here? You might want to use outside resources to understand what's going on.

# %% [markdown]
# Next, look at the plots of the differenced series. Use subplots to plot them rather than creating just one plot.

# %%
df_diff
# Out:
#                 Euro  Australian Dollar  Danish Krone
# Frequency
# 2000-01-01       NaN                NaN           NaN
# 2000-01-02       NaN                NaN           NaN
# 2000-01-03       NaN                NaN           NaN
# 2000-01-04 -0.020677           0.000388     -0.151424
# 2000-01-05 -0.005897           0.000016     -0.042440
# 2000-01-06 -0.001857           0.002365     -0.014113
# 2000-01-07  0.009735           0.006657      0.071983
# 2000-01-08       NaN                NaN           NaN
# 2000-01-09       NaN                NaN           NaN
# 2000-01-10       NaN                NaN           NaN
# 2000-01-11 -0.002574           0.003496     -0.019551
# 2000-01-12 -0.004919          -0.008772     -0.035743
# 2000-01-13  0.003021          -0.015026      0.022200
# 2000-01-14  0.004854          -0.004041      0.036039
# 2000-01-15       NaN                NaN           NaN
# 2000-01-16       NaN                NaN           NaN
# 2000-01-17       NaN                NaN           NaN
# 2000-01-18  0.000098           0.001140      0.001821
# 2000-01-19 -0.001177          -0.001791     -0.008660
# 2000-01-20  0.001570          -0.001576      0.012773
# 2000-01-21 -0.000786           0.002076     -0.005451
# 2000-01-22       NaN                NaN           NaN
# 2000-01-23       NaN                NaN           NaN
# 2000-01-24       NaN                NaN           NaN
# 2000-01-25  0.001894           0.000898      0.012299
# 2000-01-26 -0.001097          -0.000977     -0.008965
# 2000-01-27  0.004302           0.007276      0.032122
# 2000-01-28  0.013029           0.008649      0.096265
# 2000-01-29       NaN                NaN           NaN
# 2000-01-30       NaN                NaN           NaN
# ...              ...                ...           ...
# 2018-10-28       NaN                NaN           NaN
# 2018-10-29       NaN                NaN           NaN
# 2018-10-30  0.000696          -0.002049      0.005189
# 2018-10-31  0.004195           0.002040      0.031305
# 2018-11-01 -0.005816          -0.019383     -0.044277
# 2018-11-02 -0.001845          -0.004415     -0.013852
# 2018-11-03       NaN                NaN           NaN
# 2018-11-04       NaN                NaN           NaN
# 2018-11-05       NaN                NaN           NaN
# 2018-11-06 -0.004463          -0.008279     -0.033560
# 2018-11-07 -0.004495          -0.010492     -0.033090
# 2018-11-08  0.004801           0.000384      0.035725
# 2018-11-09  0.006018           0.008988      0.044627
# 2018-11-10       NaN                NaN           NaN
# 2018-11-11       NaN                NaN           NaN
# 2018-11-12       NaN                NaN           NaN
# 2018-11-13  0.000316           0.000937      0.003773
# 2018-11-14 -0.002752          -0.001733     -0.019821
# 2018-11-15 -0.000705          -0.009330     -0.005171
# 2018-11-16 -0.003196           0.000225     -0.024205
# 2018-11-17       NaN                NaN           NaN
# 2018-11-18       NaN                NaN           NaN
# 2018-11-19       NaN                NaN           NaN
# 2018-11-20  0.000460           0.005273      0.003606
# 2018-11-21  0.000921           0.002587      0.005997
# 2018-11-22  0.000461           0.000374      0.003353
# 2018-11-23  0.003940           0.005049      0.029574
# 2018-11-24       NaN                NaN           NaN
# 2018-11-25       NaN                NaN           NaN
# 2018-11-26       NaN                NaN           NaN
#
# [6905 rows x 3 columns]

# %%
# your code here
df_diff = df.diff(periods=1)

# %%
df_diff.plot(figsize=(10,8),subplots=True, legend=True)
plt.show()

# %%
# your code here

# %% [markdown]
# ### Explain what's going on

# %% [markdown]
# Next, let's look at the "lag 1 autocorrelation" for the EUR/USD exchange rate. Create a "lag 1 autocorrelation" series, plot the result, and look at the correlation coefficient.

# %%
# your code here
df_diff.corr()
# Out:
#                        Euro  Australian Dollar  Danish Krone
# Euro               1.000000           0.545369      0.999667
# Australian Dollar  0.545369           1.000000      0.545133
# Danish Krone       0.999667           0.545133      1.000000

# %%
# your code here
eur = df[['Euro']]

# %%
# your code here
eur_shift_1 = eur.shift(periods=1)
eur_shift_1.head()

lag_1= pd.concat([eur_shift_1, eur], axis=1)
lag_1.plot(figsize=(18,6), alpha=0.5);

# %%
lag_1.corr()
# Out:
#           Euro      Euro
# Euro  1.000000  0.999146
# Euro  0.999146  1.000000

# %% [markdown]
# Repeat this, but for a "lag 5 autocorrelation"

# %%
# your code here
eur_shift_50 = eur.shift(periods=50)
eur_shift_50.head()

lag_50= pd.concat([eur_shift_50, eur], axis=1)
lag_50.plot(figsize=(18,6), alpha=0.8);

# %%
# your code here
lag_50.corr()
# Out:
#           Euro      Euro
# Euro  1.000000  0.968321
# Euro  0.968321  1.000000

# %% [markdown]
# ### What's your conclusion here?

# %% [markdown]
# Knowing this, let's plot the ACF now.

# %%
# your code here
pd.plotting.autocorrelation_plot(eur.dropna());

# %% [markdown]
# The series is heavily autocorrelated at first, and then there is a decay. This is a typical result for a series that is a random walk, generally you'll see heavy autocorrelations first, slowly tailing off until there is no autocorrelation anymore.

# %% [markdown]
# Next, let's look at the Partial Autocorrelation Function.

# %%
# your code here
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib.pylab import rcParams

rcParams['figure.figsize'] = 14, 5

plot_pacf(eur.dropna(), lags = 100);

# %% [markdown]
# This is interesting! Remember that *Partial Autocorrelation Function* gives the partial correlation of a time series with its own lagged values, controlling for the values of the time series at all shorter lags. When controlling for 1 period lags, the PACF is only very high for one-period lags, and basically 0 for shorter lags. This is again a typical result for Random Walk series!

# %% [markdown]
# ## The Airpassenger Data

# %% [markdown]
# Look at ACF and PACF for the airpassenger data and describe the result `passengers.csv`. Do this both for the differenced and regular series.

# %%
# your code here
air= pd.read_csv('passengers.csv')
air.Month = pd.to_datetime(air.Month)
air.set_index('Month', inplace = True)

# %%
# your code here
air.plot()

# %%
# your code here
plt.figure(figsize=(12,5))
pd.plotting.autocorrelation_plot(air);

# %%
# your code here
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 14, 5
plot_pacf(air.dropna(), lags = 100);
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
# your code here
air_diff = air.diff(periods=1)

# %%
# your code here
plt.figure(figsize=(12,5))
pd.plotting.autocorrelation_plot(air_diff.dropna());

# %%
# your code here
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib.pylab import rcParams

rcParams['figure.figsize'] = 14, 5

plot_pacf(air_diff.dropna(), lags = 100);
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# ### Your conclusion here

# %% [markdown]
# ## The NYSE data

# %% [markdown]
# Look at correlation and autocorrelation functions for the NYSE data ("NYSE_monthly.csv")

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %% [markdown]
# ## Your conclusion here

# %% [markdown]
# ## Summary
#
# Great, you've now been introduced to correlation, the ACF and PACF. Let's move into more serious modeling with autoregressive and moving average models!
